# %% [markdown]
# # Exel-tiedosto dataframeksi ja siitä tekstitiedostoksi

# %%
# Määritetään dataframeksi exeltiedosto
import pandas as pd
df = pd.read_excel('sukunimitilasto-2021-02-05-dvv.xlsx')

# %%
df
# Out:
#         Sukunimi  Yhteensä
# 0       Korhonen     22204
# 1       Virtanen     21578
# 2        Mäkinen     19874
# 3       Nieminen     19668
# 4         Mäkelä     18809
# ...          ...       ...
# 22875    Åbrandt        20
# 22876   Åkerblad        20
# 22877    Äimänen        20
# 22878       Ämtö        20
# 22879  Övergaard        20
#
# [22880 rows x 2 columns]

# %%
# Poistetaan kaikki nimet joita on alle 1000 kpl
df = df[df['Yhteensä'] >= 1000]

# %%
df['Yhteensä'].min()
# Out:
# 1000

# %%
# Poistetaan nyt lukumääräsarake
df = df.drop(columns=['Yhteensä'])

# %%
df
# Out:
#        Sukunimi
# 0      Korhonen
# 1      Virtanen
# 2       Mäkinen
# 3      Nieminen
# 4        Mäkelä
# ..          ...
# 867   Saloranta
# 868      Yrjölä
# 869  Myllykoski
# 870        Palm
# 871    Björkman
#
# [872 rows x 1 columns]

# %%
# Tallennetaan tekstitiedostoksi
import numpy as np
df.to_csv("finnish.txt", header=None, index=None, sep=',', mode='w')

# %% [markdown]
# ### Kopioidaan ja siirretään tekstitiedosto muiden nimitiedostojen joukkoon => `.data/names/`

# %%
import pandas as pd
df = pd.read_csv('finnish.txt')

# %%
df
# Out:
#        Korhonen
# 0      Virtanen
# 1       Mäkinen
# 2      Nieminen
# 3        Mäkelä
# 4    Hämäläinen
# ..          ...
# 866   Saloranta
# 867      Yrjölä
# 868  Myllykoski
# 869        Palm
# 870    Björkman
#
# [871 rows x 1 columns]

# %%
df.loc[df['Korhonen'] == 'Pellinen']
# Out:
#      Korhonen
# 575  Pellinen

# %%
df = pd.read_csv('eng-fin.txt', delimiter = "\t", header=None)

# %%
df
# Out:
#                                                        0  \
# 0                                                    Go.
# 1                                                    Hi.
# 2                                                    Hi.
# 3                                                   Run!
# 4                                                   Run!
# ...                                                  ...
# 63557  A child who is a native speaker usually knows ...
# 63558  In today's world, we have to equip all our kid...
# 63559  At a moment when our economy is growing, our b...
# 63560  The driver of an oncoming car flashed his ligh...
# 63561  If someone who doesn't know your background sa...
#
#                                                        1  \
# 0                                                  Mene.
# 1                                                  Moro!
# 2                                                 Terve.
# 3                                                Juokse!
# 4                                               Juoskaa!
# ...                                                  ...
# 63557  Lapsi, joka puhuu kieltä äidinkielenään, tietä...
# 63558  Nykypäivän maailmassa meidän täytyy varustaa k...
# 63559  Tällä hetkellä kun taloutemme on kasvussa, yri...
# 63560  Vastaanajavan auton kuski väläytti valojaan va...
# 63561  Jos joku, joka ei tunne taustaasi, sanoo että ...
#
#                                                        2
# 0      CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 1      CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 2      CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 3      CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 4      CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# ...                                                  ...
# 63557  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 63558  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 63559  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 63560  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 63561  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
#
# [63562 rows x 3 columns]

# %%
df= df.drop(columns=[2])

# %%
df
# Out:
#                                                        0  \
# 0                                                    Go.
# 1                                                    Hi.
# 2                                                    Hi.
# 3                                                   Run!
# 4                                                   Run!
# ...                                                  ...
# 63557  A child who is a native speaker usually knows ...
# 63558  In today's world, we have to equip all our kid...
# 63559  At a moment when our economy is growing, our b...
# 63560  The driver of an oncoming car flashed his ligh...
# 63561  If someone who doesn't know your background sa...
#
#                                                        1
# 0                                                  Mene.
# 1                                                  Moro!
# 2                                                 Terve.
# 3                                                Juokse!
# 4                                               Juoskaa!
# ...                                                  ...
# 63557  Lapsi, joka puhuu kieltä äidinkielenään, tietä...
# 63558  Nykypäivän maailmassa meidän täytyy varustaa k...
# 63559  Tällä hetkellä kun taloutemme on kasvussa, yri...
# 63560  Vastaanajavan auton kuski väläytti valojaan va...
# 63561  Jos joku, joka ei tunne taustaasi, sanoo että ...
#
# [63562 rows x 2 columns]

# %%
import numpy as np
texts = df.to_numpy()
np.savetxt("eng-fin2.txt", texts, fmt = "%s", delimiter="\t")
